# %% [markdown]
# <a href="https://colab.research.google.com/github/BusileNdhlovu/EDA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.Importing Libraries

# %%
# import numpy super easy and fast to work with large sets of numbers, especially for math, stats, and data analysis.
import numpy as np
#import pandas makes it easy to organize, clean, and analyze data
import pandas as pd

# %% [markdown]
# ## 2. Data Ingestion

# %% [markdown]
# 2.1 Location of data defined as dp

# %%
##Stores the location of the file in the variable dp
dp = "/content/drive/MyDrive/shopping trends/shopping_trends_with_processdate.csv"

# %% [markdown]
# ## 3.Reading Shopping Trend Data

# %%
#loading the file
shopping_trends_with_processdate = pd.read_csv(dp)

# %% [markdown]
# ## 4.Data Preview

# %% [markdown]
# 4.1 Quickly check how big your dataset is

# %%
shopping_trends_with_processdate.shape
# Out:
# (3900, 19)

# %% [markdown]
# 4.2 Displays the first few columns and rows of the table

# %%
display(shopping_trends_with_processdate.head())
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# 4.3 Displays the last 5 rows of the table

# %%
display(shopping_trends_with_processdate.tail())
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# ...

# %% [markdown]
# 4.4 Randomly select 5 rows from the dataset

# %%
display(shopping_trends_with_processdate.sample(5))
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3865         3866   25  Female         Shorts     Clothing
# 2783         2784   19  Female          Skirt     Clothing
# 1868         1869   23    Male         Gloves  Accessories
# 1562         1563   37    Male          Scarf  Accessories
# 1274         1275   54    Male            Hat  Accessories
#
#       Purchase Amount (USD)  Location Size   Color  Season  Review Rating  \
# 3865                     42  Nebraska    M   Olive  Spring            4.2
# 2783                     38  Virginia    M  Silver  Spring            4.5
# 1868                     58   Indiana    M  Silver  Spring            4.7
# 1562                     75   Alabama    M  Purple  Winter            3.2
# 1274                     73  Missouri    M   Olive  Spring            3.1
#
#      Subscription Status   Shipping Type Discount Applied Promo Code Used  \
# 3865                  No    Store Pickup               No              No
# ...

# %% [markdown]
# ## 5.Basic Infor and Structure

# %% [markdown]
# 5.1 Checking summary of the DataFrame’s structure

# %%
shopping_trends_with_processdate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# 5.2 Checking summary of statistics for the numerical columns in the DataFrame.

# %%
shopping_trends_with_processdate.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# 5.3 Checking column names in the dataset

# %%
shopping_trends_with_processdate.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'processdate'],
#       dtype='object')

# %% [markdown]
# 5.4 Checking if the  data types are correct for each column

# %%
shopping_trends_with_processdate.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# processdate                object
# dtype: object

# %% [markdown]
# 5.5 Exploring the uniqueness of my data, counts how many distinct values there are in each column

# %%
shopping_trends_with_processdate.nunique()
shopping_trends_with_processdate["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ## 6.Data Cleaning

# %% [markdown]
# 6.1 Checking for Missing values/Nulls

# %%
shopping_trends_with_processdate.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# processdate               0
# dtype: int64

# %% [markdown]
# Observation
#
#
# *   There are no missing/null values in any of the columns

# %% [markdown]
# 6.2 Checking for duplicate rows

# %%
shopping_trends_with_processdate.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Observation
#
#
# *   There are zero duplicated rows in this dataset
